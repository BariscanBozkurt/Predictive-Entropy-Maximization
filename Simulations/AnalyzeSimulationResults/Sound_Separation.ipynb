# %%
import sys
sys.path.insert(0, '../Results')
sys.path.insert(0, '../../src')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os
from scipy import stats

from python_utils.visualization_utils import create_summary_table, plot_snr_performance

# %%
df_predictiveBSS = pd.read_pickle(r"../Results/predictive_bss_sound_separation_5by3_results.pkl")
df_predictiveBSS.tail(30)
# Out:
#                   Model  seed       SINR  \
# 0   PredictiveDecorrBSS     0  20.866523
# 1   PredictiveDecorrBSS   100  25.458018
# 2   PredictiveDecorrBSS   200  17.973053
# 3   PredictiveDecorrBSS   300  22.208551
# 4   PredictiveDecorrBSS   400  26.141774
# 5   PredictiveDecorrBSS   500  23.814016
# 6   PredictiveDecorrBSS   600  25.364296
# 7   PredictiveDecorrBSS   700  24.427981
# 8   PredictiveDecorrBSS   800  27.311339
# 9   PredictiveDecorrBSS   900  25.583536
# 10  PredictiveDecorrBSS  1000   4.383217
# 11  PredictiveDecorrBSS  1100  21.373925
# 12  PredictiveDecorrBSS  1200  26.330885
# 13  PredictiveDecorrBSS  1300  20.186200
# 14  PredictiveDecorrBSS  1400  26.395613
# 15  PredictiveDecorrBSS  1500  24.427366
# 16  PredictiveDecorrBSS  1600  23.004117
# 17  PredictiveDecorrBSS  1700  22.815042
# 18  PredictiveDecorrBSS  1800  22.819133
# 19  PredictiveDecorrBSS  1900  23.173635
# 20  PredictiveDecorrBSS  2000  21.082203
# 21  PredictiveDecorrBSS  2100  26.613426
# ...

# %%
data = np.vstack(df_predictiveBSS["SNR"].values)

n = data.shape[0]
means = np.mean(data, axis=0)
sems = stats.sem(data, axis=0)

# 95% Confidence Interval Margin
# stats.t.ppf(0.975, df) gives the t-critical value
t_crit = stats.t.ppf(0.975, n-1)
ci_margins = t_crit * sems

for i in range(3):
    print(f"Sound {i+1}: {means[i]:.2f} +/- {ci_margins[i]:.2f} (95% CI)")
# Out:
# Sound 1: 23.91 +/- 2.09 (95% CI)
# Sound 2: 25.32 +/- 2.09 (95% CI)
# Sound 3: 21.43 +/- 2.17 (95% CI)
